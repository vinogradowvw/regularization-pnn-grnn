# %%
import numpy as np
import torch
import pandas as pd
from PNN import TrainablePNN
from GRNN import TrainableGRNN
from PNN import PNN
from GRNN import GRNN
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_breast_cancer, load_diabetes
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

from matplotlib.pylab import plt
import skfda

from sklearn.linear_model import LinearRegression, LogisticRegression

# %% [markdown]
# # Base functions

# %%
def evaluvate_on_kfold(X, y, model):
    
    model_class = model.__class__
    
    is_regression = 'GRNN' in model_class.__name__ or 'LinearRegression' in model_class.__name__
    if is_regression:
        score_func = mean_squared_error
    else:
        score_func = accuracy_score
    
    kf = KFold(n_splits=4)

    scores = []
    
    for i, (train_index, test_index) in enumerate(kf.split(X, y)):
        X_train, y_train = X[train_index], y[train_index]
        X_test, y_test = X[test_index], y[test_index]

        scaler_X = StandardScaler()
        X_train_scaled = scaler_X.fit_transform(X_train)
        X_test_scaled = scaler_X.transform(X_test)

        if is_regression:
            scaler_y = StandardScaler()
            y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).ravel()
        else:
            y_train_scaled = y_train

        model.fit(X_train_scaled, y_train_scaled)        
        
        preds_scaled = [model.predict([x_test]) for x_test in X_test_scaled]

        if is_regression:
            preds = scaler_y.inverse_transform(np.array(preds_scaled).reshape(-1, 1)).ravel()
        else:
            preds = preds_scaled
        
        scores.append(score_func(y_true=y_test, y_pred=preds))

    return np.mean(scores)

# %%
def grid_search_cv(X, y, model_class, sigma_range, tau_range, n_classes=2, losses=None):

    if losses is None:
        losses = [1] * n_classes

    if 'GRNN' in model_class.__name__:
        score_func = mean_squared_error
    else:
        score_func = accuracy_score
                
    best_sigma = None
    best_score = float('inf') if score_func == mean_squared_error else 0

    for sigma in sigma_range:
        try:
            if 'GRNN' in model_class.__name__:
                score_func = mean_squared_error
                model = model_class(kernel="gaussian", sigma=sigma)
            else:
                score_func = accuracy_score
                model = model_class(kernel="gaussian", sigma=sigma,
                                    n_classes=n_classes, losses=losses)
            score = evaluvate_on_kfold(X, y, model)
            if ((score_func == accuracy_score and score > best_score) or
                (score_func == mean_squared_error and score < best_score)):
                best_score = score
                best_sigma = sigma
        except ZeroDivisionError:
            continue

    results = []
    results.append({
        "Model": f"{model_class.__name__}",
        "Best Sigma": best_sigma,
        "Best Tau": None,
        "Score": best_score
    })

    print(f"Best sigma found: {best_sigma} (Score: {best_score:.4f})")

    regularizations = ['l1', 'l2']
    
    for reg in regularizations:
        best_tau = None
        best_score = float('inf') if score_func == mean_squared_error else 0

        for tau in tau_range:
            try:
                if 'GRNN' in model_class.__name__:
                    trainable_model_class = TrainableGRNN
                    model = trainable_model_class(sigma=best_sigma,
                                    regularization=reg, tau=tau)
                else:
                    trainable_model_class = TrainablePNN
                    model = trainable_model_class(sigma=best_sigma,
                                    regularization=reg, tau=tau,
                                    n_classes=n_classes, losses=losses)
                
                score = evaluvate_on_kfold(X, y, model)
                if ((score_func == accuracy_score and score > best_score) or
                    (score_func == mean_squared_error and score < best_score)):
                    best_score = score
                    best_tau = tau
            except ZeroDivisionError as e:
                continue

        results.append({
            "Model": f"{model_class.__name__} with {reg.upper()}",
            "Best Sigma": best_sigma,
            "Best Tau": best_tau,
            "Score": best_score
        })

    return results

# %%
all_results_data = []

# %% [markdown]
# # Breast cancer

# %%
data = load_breast_cancer()
X_train = data['data']
y_train = data['target']
print(len(X_train))
# Out:
# 569

# %%
model_class = PNN
sigma_range = np.round(np.arange(0.1, 5.1, 0.1), 2)
tau_range = np.round(np.arange(0.1, 5.1, 0.1), 2)

evals = grid_search_cv(X_train, y_train, model_class, sigma_range, tau_range, n_classes=2, losses=None)
# Out:
# Best sigma found: 0.8 (Score: 0.9649)

# %%
results_df = pd.DataFrame(evals)
results_df['Impovement %'] = np.round((results_df['Score'] / results_df['Score'].iloc[0]) * 100, 3) - 100
results_df['Dataset'] = 'Breast Cancer'
results_df['Instances'] = len(X_train)
results_df
# Out:
#          Model  Best Sigma  Best Tau     Score  Impovement %        Dataset  \
# 0          PNN         0.8       NaN  0.964863         0.000  Breast Cancer
# 1  PNN with L1         0.8       2.6  0.968371         0.364  Breast Cancer
# 2  PNN with L2         0.8       4.3  0.970157         0.549  Breast Cancer
#
#    Instances
# 0        569
# 1        569
# 2        569

# %%
# Logistic regression
evaluvate_on_kfold(X_train, y_train, LogisticRegression())
# Out:
# 0.977149610952428

# %%
all_results_data.append(results_df)

# %% [markdown]
# # Suspicious firms

# %%
df = pd.read_csv('./data/audit_risk.csv')

df = df.dropna()

df = df.drop(columns=['LOCATION_ID'])

X_train = df.drop(columns=['Risk']).values
y_train = df['Risk'].values

print(len(X_train))
# Out:
# 775

# %%
model_class = PNN
sigma_range = np.round(np.arange(0.1, 5.1, 0.1), 2)
tau_range = np.round(np.arange(0.1, 5.1, 0.1), 2)

evals = grid_search_cv(X_train, y_train, model_class, sigma_range, tau_range, n_classes=2, losses=None)
# Out:
# Best sigma found: 0.4 (Score: 0.9548)

# %%
results_df = pd.DataFrame(evals)
results_df['Impovement %'] = np.round((results_df['Score'] / results_df['Score'].iloc[0]) * 100, 3) - 100
results_df['Dataset'] = 'Suspicious firms'
results_df['Instances'] = len(X_train)
results_df
# Out:
#          Model  Best Sigma  Best Tau     Score  Impovement %  \
# 0          PNN         0.4       NaN  0.954797          0.00
# 1  PNN with L1         0.4       0.2  0.916130         -4.05
# 2  PNN with L2         0.4       0.9  0.916130         -4.05
#
#             Dataset  Instances
# 0  Suspicious firms        775
# 1  Suspicious firms        775
# 2  Suspicious firms        775

# %%
# Logistic regression
evaluvate_on_kfold(X_train, y_train, LogisticRegression())
# Out:
# 0.9806300411302815

# %%
all_results_data.append(results_df)

# %% [markdown]
# # Diabetes

# %%
data = load_diabetes()

X_train = data['data']
y_train = data['target']

print(len(X_train))
# Out:
# 442

# %%
model_class = GRNN
sigma_range = np.round(np.arange(0.1, 5.1, 0.1), 2)
tau_range = np.round(np.arange(0.1, 5.1, 0.1), 2)

evals = grid_search_cv(X_train, y_train, model_class, sigma_range, tau_range, n_classes=2, losses=None)
# Out:
# Best sigma found: 1.0 (Score: 3251.3003)

# %%
results_df = pd.DataFrame(evals)
results_df['Impovement %'] = np.round((results_df['Score'].iloc[0] / results_df['Score']) * 100, 3) - 100
results_df['Dataset'] = 'Diabetes'
results_df['Instances'] = len(X_train)
results_df
# Out:
#           Model  Best Sigma  Best Tau        Score  Impovement %   Dataset  \
# 0          GRNN         1.0       NaN  3251.300348         0.000  Diabetes
# 1  GRNN with L1         1.0       4.6  3156.055280         3.018  Diabetes
# 2  GRNN with L2         1.0       2.9  3125.045664         4.040  Diabetes
#
#    Instances
# 0        442
# 1        442
# 2        442

# %%
# Logistic regression
evaluvate_on_kfold(X_train, y_train, LinearRegression())
# Out:
# 2961.7095123449676

# %%
all_results_data.append(results_df)

# %% [markdown]
# # Concrete Compressive Strength

# %%
df = pd.read_excel('data/Concrete_Data.xls')

X_train = df.iloc[:, :-1].values
y_train = df.iloc[:, -1].values

print(len(X_train))
# Out:
# 1030

# %%
model_class = GRNN
sigma_range = np.round(np.arange(0.1, 5.1, 0.1), 2)
tau_range = np.round(np.arange(0.1, 5.1, 0.1), 2)

evals = grid_search_cv(X_train, y_train, model_class, sigma_range, tau_range, n_classes=2, losses=None)
# Out:
# Best sigma found: 0.7 (Score: 165.8447)

# %%
results_df = pd.DataFrame(evals)
results_df['Impovement %'] = np.round((results_df['Score'].iloc[0] / results_df['Score']) * 100, 3) - 100
results_df['Dataset'] = 'Concrete Compressive Strength'
results_df['Instances'] = len(X_train)
results_df
# Out:
#           Model  Best Sigma  Best Tau       Score  Impovement %  \
# 0          GRNN         0.7       NaN  165.844719         0.000
# 1  GRNN with L1         0.7       2.3  160.626478         3.249
# 2  GRNN with L2         0.7       3.3  159.922305         3.703
#
#                          Dataset  Instances
# 0  Concrete Compressive Strength       1030
# 1  Concrete Compressive Strength       1030
# 2  Concrete Compressive Strength       1030

# %%
# Logistic regression
evaluvate_on_kfold(X_train, y_train, LinearRegression())
# Out:
# 137.01758882407188

# %%
all_results_data.append(results_df)

# %% [markdown]
# # Energy Efficiency

# %%
df = pd.read_csv('data/ENB2012_data.csv')

X_train = df.drop(columns=['Y1', 'Y2']).values
y_train = df['Y1'].to_numpy()

# %%
model_class = GRNN
sigma_range = np.round(np.arange(0.1, 5.1, 0.1), 2)
tau_range = np.round(np.arange(0.1, 5.1, 0.1), 2)

evals = grid_search_cv(X_train, y_train, model_class, sigma_range, tau_range, n_classes=2, losses=None)
# Out:
# Best sigma found: 0.2 (Score: 7.4858)

# %%
results_df = pd.DataFrame(evals)
results_df['Impovement %'] = np.round((results_df['Score'].iloc[0] / results_df['Score']) * 100, 3) - 100
results_df['Dataset'] = 'Energy Efficiency'
results_df['Instances'] = len(X_train)
results_df
# Out:
#           Model  Best Sigma  Best Tau     Score  Impovement %  \
# 0          GRNN         0.2       NaN  7.485782         0.000
# 1  GRNN with L1         0.2       2.0  7.515747        -0.399
# 2  GRNN with L2         0.2       0.5  7.565055        -1.048
#
#              Dataset  Instances
# 0  Energy Efficiency        768
# 1  Energy Efficiency        768
# 2  Energy Efficiency        768

# %%
# Logistic regression
evaluvate_on_kfold(X_train, y_train, LinearRegression())
# Out:
# 10.112802196898844

# %%
all_results_data.append(results_df)

# %% [markdown]
# # Parkinsons

# %%
df = pd.read_csv('data/parkinsons.data')

X_train = df.drop(columns=['name', 'status']).to_numpy()
y_train = df['status'].to_numpy()

print(len(X_train))
# Out:
# 195

# %%
model_class = PNN
sigma_range = np.round(np.arange(0.1, 5.1, 0.1), 2)
tau_range = np.round(np.arange(0.1, 5.1, 0.1), 2)

evals = grid_search_cv(X_train, y_train, model_class, sigma_range, tau_range, n_classes=2, losses=None)
# Out:
# Best sigma found: 1.6 (Score: 0.8040)

# %%
results_df = pd.DataFrame(evals)
results_df['Impovement %'] = np.round((results_df['Score'] / results_df['Score'].iloc[0]) * 100, 3) - 100
results_df['Dataset'] = 'Parkinsons'
results_df['Instances'] = len(X_train)
results_df
# Out:
#          Model  Best Sigma  Best Tau     Score  Impovement %     Dataset  \
# 0          PNN         1.6       NaN  0.803997         0.000  Parkinsons
# 1  PNN with L1         1.6       2.3  0.839711         4.442  Parkinsons
# 2  PNN with L2         1.6       4.3  0.839711         4.442  Parkinsons
#
#    Instances
# 0        195
# 1        195
# 2        195

# %%
# Logistic regression
evaluvate_on_kfold(X_train, y_train, LogisticRegression())
# Out:
# 0.7887967687074829

# %%
all_results_data.append(results_df)

# %% [markdown]
# # Data joining

# %%
combined_df = pd.concat(all_results_data, ignore_index=True)

# %%
combined_df
# Out:
#            Model  Best Sigma  Best Tau        Score  Impovement %  \
# 0            PNN         0.8       NaN     0.964863         0.000
# 1    PNN with L1         0.8       2.6     0.968371         0.364
# 2    PNN with L2         0.8       4.3     0.970157         0.549
# 3            PNN         0.4       NaN     0.954797         0.000
# 4    PNN with L1         0.4       0.2     0.916130        -4.050
# 5    PNN with L2         0.4       0.9     0.916130        -4.050
# 6           GRNN         1.0       NaN  3251.300348         0.000
# 7   GRNN with L1         1.0       4.6  3156.055280         3.018
# 8   GRNN with L2         1.0       2.9  3125.045664         4.040
# 9           GRNN         0.7       NaN   165.844719         0.000
# 10  GRNN with L1         0.7       2.3   160.626478         3.249
# 11  GRNN with L2         0.7       3.3   159.922305         3.703
# 12          GRNN         0.2       NaN     7.485782         0.000
# 13  GRNN with L1         0.2       2.0     7.515747        -0.399
# 14  GRNN with L2         0.2       0.5     7.565055        -1.048
# 15           PNN         1.6       NaN     0.803997         0.000
# 16   PNN with L1         1.6       2.3     0.839711         4.442
# 17   PNN with L2         1.6       4.3     0.839711         4.442
#
#                           Dataset  Instances
# 0                   Breast Cancer        569
# 1                   Breast Cancer        569
# 2                   Breast Cancer        569
# 3                Suspicious firms        775
# 4                Suspicious firms        775
# 5                Suspicious firms        775
# 6                        Diabetes        442
# 7                        Diabetes        442
# 8                        Diabetes        442
# 9   Concrete Compressive Strength       1030
# 10  Concrete Compressive Strength       1030
# 11  Concrete Compressive Strength       1030
# 12              Energy Efficiency        768
# 13              Energy Efficiency        768
# 14              Energy Efficiency        768
# 15                     Parkinsons        195
# 16                     Parkinsons        195
# 17                     Parkinsons        195

# %%
results = []

for dataset in combined_df['Dataset'].unique():
    df_dataset = combined_df[combined_df['Dataset'] == dataset]
    
    for model_type in ['PNN', 'GRNN']:
        base = df_dataset[df_dataset['Model'] == model_type]
        with_l1 = df_dataset[df_dataset['Model'] == f'{model_type} with L1']
        with_l2 = df_dataset[df_dataset['Model'] == f'{model_type} with L2']
        
        if base.empty:
            continue

        score_metric = 'Accuracy' if model_type == 'PNN' else 'MSE'

        row = {
            'Dataset': dataset,
            'Score metric': score_metric,
            'Best Sigma': base['Best Sigma'].values[0],
            'Score Base': base['Score'].values[0],
            'Best tau (L1)': with_l1['Best Tau'].values[0] if not with_l1.empty else None,
            'Score L1': with_l1['Score'].values[0] if not with_l1.empty else None,
            'Impovement % (L1)': with_l1['Impovement %'].values[0] if not with_l1.empty else None,
            'Best tau (L2)': with_l2['Best Tau'].values[0] if not with_l2.empty else None,
            'Score L2': with_l2['Score'].values[0] if not with_l2.empty else None,
            'Impovement % (L2)': with_l2['Impovement %'].values[0] if not with_l2.empty else None,
            'Instances': base['Instances'].values[0]
        }
        
        results.append(row)

final_df = pd.DataFrame(results)

# %%
final_df = final_df.drop(columns=['Score metric'])

# %%
latex_table = final_df.to_latex(
    index=False,
    escape=False,
    formatters={
        'Best Sigma': '{:.1f}'.format,
        'Best tau (L1)': '{:.1f}'.format,
        'Best tau (L2)': '{:.1f}'.format,
        'Score Base': '{:.3f}'.format,
        'Score L1': '{:.3f}'.format,
        'Score L2': '{:.3f}'.format,
        'Impovement % (L1)': '{:.2f}'.format,
        'Impovement % (L2)': '{:.2f}'.format
    }
)

print(latex_table)
# Out:
# \begin{tabular}{lrrrrrrrrr}
# \toprule
# Dataset & Best Sigma & Score Base & Best tau (L1) & Score L1 & Impovement % (L1) & Best tau (L2) & Score L2 & Impovement % (L2) & Instances \\
# \midrule
# Breast Cancer & 0.8 & 0.965 & 2.6 & 0.968 & 0.36 & 4.3 & 0.970 & 0.55 & 569 \\
# Suspicious firms & 0.4 & 0.955 & 0.2 & 0.916 & -4.05 & 0.9 & 0.916 & -4.05 & 775 \\
# Diabetes & 1.0 & 3251.300 & 4.6 & 3156.055 & 3.02 & 2.9 & 3125.046 & 4.04 & 442 \\
# Concrete Compressive Strength & 0.7 & 165.845 & 2.3 & 160.626 & 3.25 & 3.3 & 159.922 & 3.70 & 1030 \\
# Energy Efficiency & 0.2 & 7.486 & 2.0 & 7.516 & -0.40 & 0.5 & 7.565 & -1.05 & 768 \\
# Parkinsons & 1.6 & 0.804 & 2.3 & 0.840 & 4.44 & 4.3 & 0.840 & 4.44 & 195 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # The effect of regularization on model error

# %%
data = load_diabetes()

X = data['data']
y = data['target']

print(len(X))
# Out:
# 442

# %%
sigma = 1
tau_range = np.round(np.arange(0.1, 5.1, 0.1), 2)

errors = []

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=12
)

scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).ravel()

for tau in tau_range:
    for reg in ['l1', 'l2']:
        
        model = TrainableGRNN(sigma=1, tau=tau, regularization=reg)

        model.fit(X_train_scaled, y_train_scaled)

        kf = KFold(n_splits=4)
        
        preds_test_scaled = [model.predict([x_test]) for x_test in X_test_scaled]
        preds_test = scaler_y.inverse_transform(np.array(preds_test_scaled).reshape(-1, 1)).ravel()
        preds_train_scaled = [model.predict([x_train]) for x_train in X_train_scaled]
        preds_train = scaler_y.inverse_transform(np.array(preds_train_scaled).reshape(-1, 1)).ravel()
        
        errors.append({
            'Regularization': reg,
            'Tau': tau,
            'MSE Test': mean_squared_error(y_true=y_test, y_pred=preds_test),
            'MSE Train': mean_squared_error(y_true=y_train, y_pred=preds_train)
        })
# Out:
# /Users/g.vinogradov/Documents/Projects/regularization-pnn-grnn/base/Layers/TrainablePatternLayerGRNN.py:87: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1729646995093/work/torch/csrc/utils/tensor_new.cpp:281.)
#   input = torch.tensor(input, dtype=torch.float32)

# %%
model = GRNN(sigma=sigma, kernel='gaussian')

model.fit(X_train_scaled, y_train)
    
model.fit(X_train_scaled, y_train_scaled)

kf = KFold(n_splits=4)

preds_test_scaled = [model.predict([x_test]) for x_test in X_test_scaled]
preds_test = scaler_y.inverse_transform(np.array(preds_test_scaled).reshape(-1, 1)).ravel()
preds_train_scaled = [model.predict([x_train]) for x_train in X_train_scaled]
preds_train = scaler_y.inverse_transform(np.array(preds_train_scaled).reshape(-1, 1)).ravel()

mse_base_test = mean_squared_error(y_true=y_test, y_pred=preds_test)
mse_base_train = mean_squared_error(y_true=y_train, y_pred=preds_train)

# %%
errors_df = pd.DataFrame(errors)
l1_errors = errors_df[errors_df['Regularization'] == 'l1']
l2_errors = errors_df[errors_df['Regularization'] == 'l2']

plt.plot(l1_errors['Tau'], l1_errors['MSE Test'], label='MSE on test data', color='blue')
plt.plot(l1_errors['Tau'], l1_errors['MSE Train'], label='MSE on train data', color='orange')

plt.axhline(mse_base_test, linestyle='--', color='blue', label='Base test accuracy')
plt.axhline(mse_base_train, linestyle='--', color='orange', label='Base train accuracy')

plt.legend()
plt.xlabel('Tau')
plt.ylabel('MSE')

plt.legend()
plt.savefig('./visualization/l1grnntesttrain.png')
plt.show()

# %%
plt.plot(l2_errors['Tau'], l2_errors['MSE Test'], label='MSE on test data', color='blue')
plt.plot(l2_errors['Tau'], l2_errors['MSE Train'], label='MSE on train data', color='orange')

plt.axhline(mse_base_test, linestyle='--', color='blue', label='Base test accuracy')
plt.axhline(mse_base_train, linestyle='--', color='orange', label='Base train accuracy')

plt.legend()
plt.xlabel('Tau')
plt.ylabel('MSE')

plt.legend()
plt.savefig('./visualization/l2grnntesttrain.png')
plt.show()
